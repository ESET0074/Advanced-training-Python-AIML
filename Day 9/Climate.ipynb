# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/kaggle/input/climate/DailyDelhiClimateTrain.csv", parse_dates=["date"])

# %%
df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   datetime64[ns]
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 57.2 KB

# %%
df.describe()
# Out:
#                       date     meantemp     humidity   wind_speed  \
# count                 1462  1462.000000  1462.000000  1462.000000
# mean   2015-01-01 12:00:00    25.495521    60.771702     6.802209
# min    2013-01-01 00:00:00     6.000000    13.428571     0.000000
# 25%    2014-01-01 06:00:00    18.857143    50.375000     3.475000
# 50%    2015-01-01 12:00:00    27.714286    62.625000     6.221667
# 75%    2016-01-01 18:00:00    31.305804    72.218750     9.238235
# max    2017-01-01 00:00:00    38.714286   100.000000    42.220000
# std                    NaN     7.348103    16.769652     4.561602
#
#        meanpressure
# count   1462.000000
# mean    1011.104548
# min       -3.041667
# 25%     1001.580357
# 50%     1008.563492
# 75%     1014.944901
# max     7679.333333
# std      180.231668

# %%
df.isnull().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
df=df.sort_values('date').reset_index(drop=True)

# %% [markdown]
# Sorting according to dates

# %%
df=df.set_index('date')

# %%
df.index.is_monotonic_increasing #checking if data is sorted properly
# Out:
# True

# %%
df.index.duplicated().sum()
# Out:
# 0

# %%
df.asfreq('D').isnull().sum() ##checking for any skipped dates
# Out:
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %% [markdown]
# ## Visualizing variance over the years

# %%
for cols in df.columns[df.columns!='date']:
    plt.figure(figsize=(15,8))
    for start_year in [2013, 2015]:
        mask = (df.index.year >= start_year) & (df.index.year < start_year + 1)
        subset = df.loc[mask, cols]
    
        # Convert to day-of-year for x-axis
        x = subset.index.dayofyear
        
        plt.plot(x, subset, label=f'{start_year}')
    
    plt.xlabel("Day of Year")
    plt.ylabel(cols)
    plt.title(f"{cols} — Yearly Overlay")
    plt.legend()
    plt.show()

# %%
df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.columns
# Out:
# Index(['meantemp', 'humidity', 'wind_speed', 'meanpressure'], dtype='object')

# %%
for cols in df.columns:
    print(cols)
    print(f"mean: {df.groupby(df.index.year)[cols].mean()}")
    print(f"max: {df.groupby(df.index.year)[cols].max()}")
    print(f"min: {df.groupby(df.index.year)[cols].min()}")
# Out:
# meantemp
# mean: date
# 2013    24.791494
# 2014    25.010673
# 2015    25.114591
# 2016    27.103373
# 2017    10.000000
# Name: meantemp, dtype: float64
# max: date
# 2013    38.714286
# 2014    38.500000
# 2015    37.750000
# 2016    38.272727
# 2017    10.000000
# Name: meantemp, dtype: float64
# min: date
# 2013     6.0000
# 2014     9.0000
# 2015     9.6250
# 2016    11.1875
# 2017    10.0000
# Name: meantemp, dtype: float64
# humidity
# mean: date
# 2013     63.046292
# 2014     59.767942
# 2015     61.430490
# 2016     58.740174
# 2017    100.000000
# Name: humidity, dtype: float64
# max: date
# 2013     94.000000
# 2014     96.857143
# 2015     98.000000
# 2016     94.300000
# 2017    100.000000
# Name: humidity, dtype: float64
# min: date
# 2013     15.857143
# 2014     20.875000
# 2015     13.428571
# 2016     18.466667
# 2017    100.000000
# Name: humidity, dtype: float64
# wind_speed
# mean: date
# 2013    6.827253
# 2014    6.756148
# 2015    6.480603
# 2016    7.162480
# 2017    0.000000
# Name: wind_speed, dtype: float64
# max: date
# 2013    42.220000
# 2014    30.685714
# 2015    33.325000
# 2016    22.100000
# 2017     0.000000
# Name: wind_speed, dtype: float64
# min: date
# 2013    0.0
# 2014    0.0
# 2015    0.0
# 2016    0.0
# 2017    0.0
# Name: wind_speed, dtype: float64
# meanpressure
# mean: date
# 2013    1007.642172
# 2014    1008.347166
# 2015    1008.834821
# 2016    1019.557460
# 2017    1016.000000
# Name: meanpressure, dtype: float64
# max: date
# 2013    1021.800000
# 2014    1023.000000
# 2015    1022.000000
# 2016    7679.333333
# 2017    1016.000000
# Name: meanpressure, dtype: float64
# min: date
# 2013     993.250000
# 2014     991.375000
# 2015     993.750000
# 2016      -3.041667
# 2017    1016.000000
# Name: meanpressure, dtype: float64

# %%
for col in df.columns:
    stats = df.groupby(df.index.year)[col].agg(['mean', 'max', 'min'])
    stats.plot(kind='bar', figsize=(8,4))
    plt.title(f"{col} — Yearly Mean, Max & Min", fontsize=13)
    plt.ylabel(col)
    plt.xlabel("Year")
    plt.xticks(rotation=0)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %%
df['month']=df.index.month
df['year']=df.index.year
df['day']=df.index.day

# %%
temp=pd.DataFrame(df.groupby(['year','month'])['meantemp'].mean())
temp=temp.reset_index()

# %%
hottest = temp.loc[temp.groupby('year')['meantemp'].idxmax()]
hottest
# Out:
#     year  month   meantemp
# 4   2013      5  33.776767
# 17  2014      6  34.770833
# 28  2015      5  33.352535
# 41  2016      6  34.946836
# 48  2017      1  10.000000

# %% [markdown]
# ## hottest month of each year

# %%
coldest = temp.loc[temp.groupby('year')['meantemp'].idxmin()]
coldest
# Out:
#     year  month   meantemp
# 0   2013      1  12.074770
# 12  2014      1  13.431836
# 24  2015      1  12.708525
# 36  2016      1  15.139363
# 48  2017      1  10.000000

# %% [markdown]
# ## coldest month of each year

# %%
tempest=pd.DataFrame(df.groupby(['year'])['wind_speed'].max())
tempest=tempest.reset_index()

# %%
for i,r in df.iterrows():
    for j,k in tempest.iterrows():
        if (k['year'] == r.year and k['wind_speed'] == r['wind_speed']):
            print(r.year,r.month,r.day,r.wind_speed)
# Out:
# 2013.0 9.0 9.0 42.22
# 2014.0 9.0 23.0 30.685714285714283
# 2015.0 8.0 19.0 33.325
# 2016.0 3.0 22.0 22.1
# 2017.0 1.0 1.0 0.0

# %% [markdown]
# ## Days of year with maximum wind speed

# %%
# Out:
#              meantemp    humidity  wind_speed  meanpressure  month  year  day
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667      1  2013    1
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000      1  2013    2
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667      1  2013    3
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667      1  2013    4
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000      1  2013    5
# ...               ...         ...         ...           ...    ...   ...  ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217     12  2016   28
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762     12  2016   29
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762     12  2016   30
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000     12  2016   31
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000      1  2017    1
#
# [1462 rows x 7 columns]

# %% [markdown]
# Outlier Analysis

# %%
num_cols = ['meantemp', 'humidity', 'wind_speed', 'meanpressure']

Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_iqr = ((df[num_cols] < lower_bound) | (df[num_cols] > upper_bound))
print("Outliers per column (IQR method):")
print(outliers_iqr.sum())

df['IQR_Outlier'] = outliers_iqr.any(axis=1)
# Out:
# Outliers per column (IQR method):
# meantemp         0
# humidity         2
# wind_speed      30
# meanpressure     9
# dtype: int64

# %%
from scipy.stats import zscore
z_scores = np.abs(df[num_cols].apply(zscore))
threshold = 3
outliers_z = (z_scores > threshold)

print("Outliers per column (Z-score method):")
print(outliers_z.sum())

df['Z_Outlier'] = outliers_z.any(axis=1)
# Out:
# Outliers per column (Z-score method):
# meantemp         0
# humidity         0
# wind_speed      14
# meanpressure     4
# dtype: int64

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
total_outliers_iqr = df['IQR_Outlier'].sum()
total_outliers_z = df['Z_Outlier'].sum()

print(f"Total rows flagged by IQR method: {total_outliers_iqr}")
print(f"Total rows flagged by Z-score method: {total_outliers_z}")

print(f"\nPercentage of outliers (IQR): {100 * total_outliers_iqr / len(df):.2f}%")
print(f"Percentage of outliers (Z-score): {100 * total_outliers_z / len(df):.2f}%")
# Out:
# Total rows flagged by IQR method: 41
# Total rows flagged by Z-score method: 18
#
# Percentage of outliers (IQR): 2.80%
# Percentage of outliers (Z-score): 1.23%

# %%
df['Outlier'] = df['IQR_Outlier'] | df['Z_Outlier']
print(f"Final outlier count (either method): {df['Outlier'].sum()}")
print("\nSample outlier rows:")
print(df[df['Outlier']].head())
# Out:
# Final outlier count (either method): 41
#
# Sample outlier rows:
#              meantemp   humidity  wind_speed  meanpressure  month  year  day  \
# date
# 2013-03-01  17.333333  49.333333   24.066667   1016.333333      3  2013    1
# 2013-05-01  31.857143  15.857143   12.685714   1002.833333      5  2013    1
# 2013-08-24  32.000000  71.250000   18.525000   1000.333333      8  2013   24
# 2013-09-09  31.000000  57.500000   42.220000   1007.000000      9  2013    9
# 2013-11-08  18.000000  82.200000   19.912500   1015.625000     11  2013    8
#
#             IQR_Outlier  Z_Outlier  Outlier
# date
# 2013-03-01         True       True     True
# 2013-05-01         True      False     True
# 2013-08-24         True      False     True
# 2013-09-09         True       True     True
# 2013-11-08         True      False     True

# %%
plt.figure(figsize=(10,4))
plt.plot(df.index, df['meantemp'], label='MeanTemp')
plt.scatter(df[df['Outlier']].index, df[df['Outlier']]['meantemp'], color='red', label='Outliers')
plt.legend()
plt.title("Mean Temperature with Outliers Highlighted")
plt.show()
